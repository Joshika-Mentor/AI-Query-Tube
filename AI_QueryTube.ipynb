# %% [markdown]
# <a href="https://colab.research.google.com/github/Joshika-Mentor/AI-Query-Tube/blob/Anukriti/AI_QueryTube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests pandas

# %%
import requests
import pandas as pd

# Replace with your own API key and Channel ID
API_KEY = "AIzaSyAHX84rZcpMrKojHSD-i2NIdz0954d6uTo"
CHANNEL_ID = "UCJskGeByzRRSvmOyZOz61ig"

url = "https://www.googleapis.com/youtube/v3/search"

params = {
    "key": API_KEY,
    "channelId": CHANNEL_ID,
    "part": "snippet,id",
    "order": "date",
    "maxResults": 50
}

# Send request
response = requests.get(url, params=params).json()

videos = []

# Extract required details
for item in response["items"]:
    if "videoId" in item["id"]:
        video_id = item["id"]["videoId"]
        title = item["snippet"]["title"]
        published = item["snippet"]["publishedAt"]
        videos.append([video_id, title, published])

# Convert to DataFrame
df = pd.DataFrame(videos, columns=["video_id", "title", "published_date"])

# Show output
df.head()
# Out:
#       video_id                                              title  \
# 0  4Xh9DLUQCWs           Launching the best DSA Course + Platform
# 1  z9bJUPxzFOw                           L18. Implement LRU Cache
# 2  cEadsbTeze4  L17. The Celebrity Problem | Stack and Queue P...
# 3  jmbuRzYPGrg    L14. Remove K Digits | Stack and Queue Playlist
# 4  _eYGqw_VDR4  L11. Aestroid Collisions | Stack and Queue Pla...
#
#          published_date
# 0  2024-08-07T12:39:14Z
# 1  2024-07-16T17:27:12Z
# 2  2024-07-16T17:26:12Z
# 3  2024-07-16T17:18:29Z
# 4  2024-07-16T17:14:25Z

# %%
df.to_csv("youtube_metadata.csv",index=False)
df
# Out:
#        video_id                                              title  \
# 0   4Xh9DLUQCWs           Launching the best DSA Course + Platform
# 1   z9bJUPxzFOw                           L18. Implement LRU Cache
# 2   cEadsbTeze4  L17. The Celebrity Problem | Stack and Queue P...
# 3   jmbuRzYPGrg    L14. Remove K Digits | Stack and Queue Playlist
# 4   _eYGqw_VDR4  L11. Aestroid Collisions | Stack and Queue Pla...
# 5   v0e8p9JCgRc  L9. Sum of Subarray Minimum | Stack and Queue ...
# 6   gIrMptNPf5M  L10. Sum of subarray ranges | Stack and Queue ...
# 7   1_5VuquLbXg  L8. Trapping Rainwater | 2 Approaches | Stack ...
# 8   zMdbdGJNlh4  L7. Previous Smaller Element | Stack and Queue...
# 9   7PrncD7v9YQ  L6. Next Greater Element - II | Stack and Queu...
# 10  NdDIaH91P0g  L4. Implement Min Stack | Stack and Queue Play...
# 11  e7XQLtOQM3I  L5. Next Greater Element | Stack and Queue Pla...
# 12  xwjS0iZhw4I  L2. Check for Balanced Parentheses | Stack and...
# ...

# %%
# !pip install youtube-transcript-api
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.1/485.1 kB 11.4 MB/s eta 0:00:00
# ...

# %%
from youtube_transcript_api import YouTubeTranscriptApi

transcripts = []
for vid in df["video_id"]:
    try:
        transcript = YouTubeTranscriptApi.get_transcript(vid)
        text = " ".join([t["text"] for t in transcript])
        transcripts.append(text)
    except:
        transcripts.append(None)

df["transcript"] = transcripts
df.head()


print(df)
# Out:
#        video_id                                              title  \
# 0   4Xh9DLUQCWs           Launching the best DSA Course + Platform
# 1   z9bJUPxzFOw                           L18. Implement LRU Cache
# 2   cEadsbTeze4  L17. The Celebrity Problem | Stack and Queue P...
# 3   jmbuRzYPGrg    L14. Remove K Digits | Stack and Queue Playlist
# 4   _eYGqw_VDR4  L11. Aestroid Collisions | Stack and Queue Pla...
# 5   v0e8p9JCgRc  L9. Sum of Subarray Minimum | Stack and Queue ...
# 6   gIrMptNPf5M  L10. Sum of subarray ranges | Stack and Queue ...
# 7   1_5VuquLbXg  L8. Trapping Rainwater | 2 Approaches | Stack ...
# 8   zMdbdGJNlh4  L7. Previous Smaller Element | Stack and Queue...
# 9   7PrncD7v9YQ  L6. Next Greater Element - II | Stack and Queu...
# 10  NdDIaH91P0g  L4. Implement Min Stack | Stack and Queue Play...
# 11  e7XQLtOQM3I  L5. Next Greater Element | Stack and Queue Pla...
# 12  xwjS0iZhw4I  L2. Check for Balanced Parentheses | Stack and...
# ...

# %%
# !pip install sentence-transformers
from sentence_transformers import SentenceTransformer
# Out:
# ...
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# ...

# %%
df["text_for_embedding"] = df["title"] + " " + df["transcript"].fillna("")

# %%
corpus = df["text_for_embedding"].tolist()

# %%
df["embedding"] = df["text_for_embedding"].apply(lambda x: model.encode(x))

# %%
from sklearn.metrics.pairwise import cosine_similarity

query = "DSA"
query_embedding = model.encode(query)

scores = cosine_similarity([query_embedding], list(df["embedding"]))
top_idx = scores[0].argsort()[-5:][::-1]  # Top 5 results
df.iloc[top_idx][["title","video_id"]]
# Out:
#                                                 title     video_id
# 0            Launching the best DSA Course + Platform  4Xh9DLUQCWs
# 38  L8. Smallest Prime Factor (SPF) | Prime Factor...  glKWkmKFlMw
# 15                 L13. Fractional Knapsack Algorithm  1ibsQrnuEEg
# 37  L1. Introduction to Sliding Window and 2 Point...  9kdHxplyl5I
# 14  L1. Introduction to Stack and Queue | Implemen...  tqQ5fTamIN4

# %%
results = df.iloc[top_idx] [["title", "video_id"]].copy()
results["score"] = scores[0][top_idx]
print(results)
# Out:
#                                                 title     video_id     score
# 0            Launching the best DSA Course + Platform  4Xh9DLUQCWs  0.555066
# 38  L8. Smallest Prime Factor (SPF) | Prime Factor...  glKWkmKFlMw  0.177442
# 15                 L13. Fractional Knapsack Algorithm  1ibsQrnuEEg  0.147189
# 37  L1. Introduction to Sliding Window and 2 Point...  9kdHxplyl5I  0.145435
# 14  L1. Introduction to Stack and Queue | Implemen...  tqQ5fTamIN4  0.129971
