# %% [markdown]
# # Final Index & Search Demo
#
# Building the index and running sample queries.

# %%
# !python ../src/embeddings/build_index.py --data ../data/clean_videos.parquet --model all-MiniLM-L6-v2 --out_dir ../data

# %%
# %load_ext autoreload
# %autoreload 2
from src.search.query_service import SearchEngine

engine = SearchEngine(index_path="../data/video_index.faiss", meta_path="../data/video_index.parquet")

# %%
results = engine.search("how to deploy python app", top_k=3)
for r in results:
    print(f"{r['score']:.3f}: {r['title']}")
