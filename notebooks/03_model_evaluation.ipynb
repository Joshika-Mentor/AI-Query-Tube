# %% [markdown]
# # Model Evaluation
#
# Running evaluation metrics on different SentenceTransformer models.

# %%
# !python ../src/embeddings/evaluate_models.py --data ../data/clean_videos.parquet --out ../results/eval_summary.csv

# %%
import pandas as pd
df = pd.read_csv("../results/eval_summary.csv")
df
