# %% [markdown]
# # Data Collection
#
# This notebook demonstrates how to fetch data from YouTube using the scripts in `src/data`.

# %%
# %load_ext autoreload
# %autoreload 2

import os
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv("YT_API_KEY")
CHANNEL_ID = os.getenv("CHANNEL_ID")

print(f"Using Channel ID: {CHANNEL_ID}")

# %%
# !python ../src/data/fetch_youtube.py --api_key $API_KEY --channel_id $CHANNEL_ID --out ../data/raw_videos.parquet

# %%
import pandas as pd
df = pd.read_parquet("../data/raw_videos.parquet")
df.head()

# %%
# !python ../src/data/fetch_transcripts.py --in_file ../data/raw_videos.parquet --out ../data/transcripts.parquet
