# %% [markdown]
# # Data Cleaning & Preprocessing
#
# Cleaning transcripts and preparing text for embedding.

# %%
# !python ../src/data/preprocess.py --in_file ../data/transcripts.parquet --out ../data/clean_videos.parquet --mode combined

# %%
import pandas as pd
df = pd.read_parquet("../data/clean_videos.parquet")
print(df.shape)
df[['title', 'text_to_embed']].head()
