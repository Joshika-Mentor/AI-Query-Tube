# %% [markdown]
# <a href="https://colab.research.google.com/github/Joshika-Mentor/AI-Query-Tube/blob/Yugal/AI%20query%20tube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests pandas

# %%
import requests
import pandas as pd

API_KEY = "AIzaSyD64SaQ4oab13KlJdAc8XmPkhqTlL2ipUc"
CHANNEL_ID = "UC24K8-tMIa04qt61Npiv5KQ"

# %%
url = "https://www.googleapis.com/youtube/v3/search"
params = {
    "key": "AIzaSyD64SaQ4oab13KlJdAc8XmPkhqTlL2ipUc",
    "channelId": "UC24K8-tMIa04qt61Npiv5KQ",
    "part": "snippet,id",
    "order": "date",
    "maxResults": 50
}

response = requests.get(url, params=params).json()

videos = []
for item in response["items"]:
    if "videoId" in item["id"]:
        video_id = item["id"]["videoId"]
        title = item["snippet"]["title"]
        published = item["snippet"]["publishedAt"]
        videos.append([video_id, title, published])

df = pd.DataFrame(videos, columns=["video_id", "title", "published_date"])
df.head()
# Out:
#       video_id                                              title  \
# 0  iy0fgihO5S4            NEET PG 2025 | CMC Vellore cut off 2025
# 1  PSNPZuXmsYM                OBC NCL CERTIFICATE DETAILS #obcncl
# 2  n1J4QAusDdE  The complex II of Mitochondrial ETS is NEET PY...
# 3  jyeCDoUTDTU  Tamil Nadu NEET PG CUT OFF 2025 | TOP 20 PG Co...
# 4  xY3GO3IpMiw           CUET UG 2026 Application soon! #cuet2026
#
#          published_date
# 0  2025-12-11T03:31:43Z
# 1  2025-12-10T16:25:44Z
# 2  2025-12-10T03:12:59Z
# 3  2025-12-10T02:50:31Z
# 4  2025-12-09T13:49:48Z
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
# ...

# %%
df.to_csv("youtube_metadata.csv", index=False)
print(df)
# Out:
#        video_id                                              title  \
# 0   iy0fgihO5S4            NEET PG 2025 | CMC Vellore cut off 2025
# 1   PSNPZuXmsYM                OBC NCL CERTIFICATE DETAILS #obcncl
# 2   n1J4QAusDdE  The complex II of Mitochondrial ETS is NEET PY...
# 3   jyeCDoUTDTU  Tamil Nadu NEET PG CUT OFF 2025 | TOP 20 PG Co...
# 4   xY3GO3IpMiw           CUET UG 2026 Application soon! #cuet2026
# 5   8lzJQgMyvDk  NEET PG Cut off 2025 | TN NEET PG Counselling ...
# 6   NiXhuJFdjhU  SCHEDULE OF ROUND 5 &amp; ROUND 6 OF UG COUNSE...
# 7   3WUNgR2uXgE  Tamil Nadu NEET PG 2025: 2,355 candidates allo...
# 8   Q4rC3-Tv3vY                           NEET PYQ 13 #neetbiology
# 9   vVkKNd6CyCM                 5 Months study plan for NEET 2026
# 10  eRuwN8bLWjA                  NEET PG 2025 cut off #neetpg2025
# 11  otdAxRDYTEA  Certificates required for Admission #careergui...
# 12  LnG7Hyipsco  Free laptops to students #freelaptop from Dec ...
#
#           published_date
# ...
