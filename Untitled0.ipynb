# %% [markdown]
# <a href="https://colab.research.google.com/github/Joshika-Mentor/AI-Query-Tube/blob/Anji114109/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests pandas
import requests
import pandas as pd

API_KEY = "API KEY"
CHANNEL_ID = "UC8butISFwT-Wl7EV0hUK0BQ"
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.11.12)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
url = "https://www.googleapis.com/youtube/v3/search"
params = {
    "key": "APIKEY",
    "channelId": "UC8butISFwT-Wl7EV0hUK0BQ",
    "part": "snippet,id",
    "order": "date",
    "maxResults": 50
}

response = requests.get(url, params=params).json()

videos = []
for item in response["items"]:
    if "videoId" in item["id"]:
        video_id = item["id"]["videoId"]
        title = item["snippet"]["title"]
        published = item["snippet"]["publishedAt"]
        videos.append([video_id, title, published])

df = pd.DataFrame(videos, columns=["video_id", "title", "published_date"])
df.head()
# Out:
#       video_id                                              title  \
# 0  jF2FnVVc4AU        How to use the .swapcase() method in Python
# 1  UIf-SlmMays                 n8n Tutorial – Zero to Hero Course
# 2  yhTipwdwe9w                          Fun fact about JavaScript
# 3  kRv2ElPNAdY  From RNNs to Transformers: The Complete Neural...
# 4  fLnkVdDPgso                    How to split a string in Python
#
#          published_date
# 0  2025-12-12T13:18:29Z
# 1  2025-12-11T15:34:06Z
# 2  2025-12-11T12:52:21Z
# 3  2025-12-10T14:42:03Z
# 4  2025-12-10T13:29:24Z

# %%
df.to_csv("youtube_metadata.csv", index=False)
print(df)
# Out:
#        video_id                                              title  \
# 0   jF2FnVVc4AU        How to use the .swapcase() method in Python
# 1   UIf-SlmMays                 n8n Tutorial – Zero to Hero Course
# 2   yhTipwdwe9w                          Fun fact about JavaScript
# 3   kRv2ElPNAdY  From RNNs to Transformers: The Complete Neural...
# 4   fLnkVdDPgso                    How to split a string in Python
# 5   9kKNFP9srjc                  So how do closures work again...?
# 6   BMt-qvrEcFY           Build Serverless AI Agents with Langbase
# 7   VgBQ0yBSjfM  How to build your own learning path using Open...
# 8   mAFoROnOfHs  Git &amp; GitHub Crash Course for Beginners [2...
# 9   wu8npoU37cI  Become an AI Researcher Course – LLM, Math, Py...
# 10  KOutPbKc9UM  Intro to Backend Web Development – Node.js &am...
#
#           published_date
# 0   2025-12-12T13:18:29Z
# 1   2025-12-11T15:34:06Z
# 2   2025-12-11T12:52:21Z
# 3   2025-12-10T14:42:03Z
# 4   2025-12-10T13:29:24Z
# 5   2025-12-09T13:05:16Z
# 6   2025-12-08T14:25:10Z
# 7   2025-12-05T13:45:05Z
# 8   2025-12-04T16:19:42Z
# 9   2025-12-03T14:28:01Z
# 10  2025-11-17T14:00:36Z
